# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
#1 Create a Mongo Database and name it Data Tracker
mydb = myclient["DataTracker"]
myproductcol = mydb["Product_type"]

delproduct = myproductcol.delete_many({}) 
  
#2 Add your SPRINT 3 products file to MongoDB you just created
mylist = [
    { "Product_type": "Simba", "amount_purchased":45, "expirydate": "01-10-2021", "mass": "125g"},
    { "Products_type": "Lays","amount_purchased":40, "expirydate": "16-11-2020", "mass": "120g"},
    { "Products_type": "Cadbury", "amount_purchased":45, "expirydate": "18-08-2020", "mass": "80g"},
    { "Products_type": "Tex", "amount_purchased":45, "expirydate": "20-09-2020", "mass": "78g"},
    { "Products_type": "DairyMilk", "amount_purchased":45, "expirydate": "22-12-2020", "mass": "82g"},
    { "Products_type": "Coke", "amount_purchased":35, "expirydate": "15-09-2022", "mass": "2 litre"},
    { "Product_type": "Fanta","amount_purchased":20, "expirydate": "12-11-2022", "mass": "1 litre"},
    { "Product_type": "Spar-letta","amount_purchased":10, "expirydate": "17-11-2022", "mass": "1.5 litre"},
    { "Product_type": "Pepper steak", "amount_purchased":10, "expirydate": "19-07-2020", "mass": "130g"},
    { "Product_type": "Chicken", "amount_purchased":15, "expirydate": "18-07-2020", "mass": "126g"},
    { "Product_type": "Steak & Kidney", "amount_purchased":25, "expirydate": "17-07-2020", "mass": "126g"},
    { "Product_type": "Pear", "amount_purchased":5, "expirydate": "20-07-2020", "mass": "178g"},
    { "Product_type": "Orange", "amount_purchased":15, "expirydate": "15-08-2020", "mass": "140g"},
    { "Product_type": "Plums", "amount_purchased":8, "expirydate": "15-08-2020", "mass": "100g"},
    { "Product_type": "Vanilla", "amount_purchased":40, "expirydate": "18-07-2020", "mass": "80g"},
    { "Product_type": "Chocolate", "amount_purchased":35, "expirydate": "20-07-2020", "mass": "78g"},
    { "Product_type": "Custurd", "amount_purchased":15, "expirydate": "22-07-2020", "mass": "82g"},
    { "Product_type": "Cabbage", "amount_purchased":20, "expirydate": "25-07-2020", "mass": "794g"},
    { "Product_type": "Spinach", "amount_purchased":10, "expirydate": "29-07-2020", "mass": "250g"},
    { "Product_type": "Potatoes", "amount_purchased":5, "expirydate": "27-07-2020", "mass": "25kg"},
    { "Product_type": "Ricoffy", "amount_purchased":50, "expirydate": "05-10-2027", "mass": "170g"},
    { "Product_type": "Folgers", "amount_purchased":45, "expirydate": "06-02-2030", "mass": "225g"},
    { "Product_type": "Nescafe", "amount_purchased":25, "expirydate": "12-01-2025", "mass": "400g"},
    
]
x = myproductcol.insert_many(mylist)


#3 Create a collection for your top 3 products in MongoDB
mynewcol =  mydb["NewProducts"]

delnew = mynewcol.delete_many({}) 
mynewlist = [
  { "_id": 1, "NewProducts": "Simba", "amount_purchased": 45 , "expirydate": "01-10-2021", "mass": "125g"},
  { "_id": 2, "NewProducts": "Lays", "amount_purchased": 40, "expirydate": "16-11-2020", "mass": "120g"},
  { "_id": 3, "NewProducts": "Cadbury", "amount_purchased": 45, "expirydate": "18-08-2020", "mass": "80g"},

#4 Insert multiple documents into your collections in question (3)
  { "_id": 4,  "NewProducts": "Tex", "amount_purchased":45, "expirydate": "20-09-2020", "mass": "78g"},
  { "_id": 5,  "NewProducts": "DairyMilk", "amount_purchased":45, "expirydate": "22-12-2020", "mass": "82g"},
  { "_id": 6,  "NewProducts": "Coke", "amount_purchased":35, "expirydate": "15-09-2022", "mass": "2 litre"},
  { "_id": 7,  "NewProducts": "Fanta","amount_purchased":20, "expirydate": "12-11-2022", "mass": "1 litre"},
  { "_id": 8,  "NewProducts": "Spar-letta","amount_purchased":10, "expirydate": "17-11-2022", "mass": "1.5 litre"},
  { "_id": 9,  "NewProducts": "Pepper steak", "amount_purchased":10, "expirydate": "19-07-2020", "mass": "130g"},
  { "_id": 10, "NewProducts": "Chicken", "amount_purchased":15, "expirydate": "18-07-2020", "mass": "126g"},
  { "_id": 11, "NewProducts": "Steak & Kidney", "amount_purchased":25, "expirydate": "17-07-2020", "mass": "126g"},
  { "_id": 12, "NewProducts": "Pear", "amount_purchased":5, "expirydate": "20-07-2020", "mass": "178g"},
  { "_id": 13, "NewProducts": "Orange", "amount_purchased":15, "expirydate": "15-08-2020", "mass": "140g"},
  { "_id": 14, "NewProducts": "Plums", "amount_purchased":8, "expirydate": "15-08-2020", "mass": "100g"},
  { "_id": 15, "NewProducts": "Vanilla", "amount_purchased":40, "expirydate": "18-07-2020", "mass": "80g"},
  { "_id": 16, "NewProducts": "Chocolate", "amount_purchased":35, "expirydate": "20-07-2020", "mass": "78g"},
  { "_id": 17, "NewProducts": "Custurd", "amount_purchased":15, "expirydate": "22-07-2020", "mass": "82g"},
  { "_id": 18, "NewProducts": "Cabbage", "amount_purchased":20, "expirydate": "25-07-2020", "mass": "794g"},
  { "_id": 19, "NewProducts": "Spinach", "amount_purchased":10, "expirydate": "29-07-2020", "mass": "250g"},
  { "_id": 20, "NewProducts": "Potatoes", "amount_purchased":5, "expirydate": "27-07-2020", "mass": "25kg"},
  { "_id": 21, "NewProducts": "Ricoffy", "amount_purchased":50, "expirydate": "05-10-2027", "mass": "170g"},
  { "_id": 22, "NewProducts": "Folgers", "amount_purchased":45, "expirydate": "06-02-2030", "mass": "225g"},
  { "_id": 23, "NewProducts": "Nescafe", "amount_purchased":25, "expirydate": "12-01-2025", "mass": "400g"},
]
x = mynewcol.insert_many(mynewlist)

#Implement a descending sort to your data in MongoDB.
mydoc = mynewcol.find().sort("NewProducts", -1)
for x in mydoc:
    print(x)
    
#Delete 2 brands from your collection of top 3 products.
query = {"NewProducts": {"$regex": "Lays|Cadbury"}} 
coldel = mynewcol.delete_many(query) 
print(f'{coldel.deleted_count} brands have been deleted from the collection.')


#Update 1 product and its brands from your collection you created in question (3).
myquery = {"NewProducts": "Cabbage","amount_purchased":20, "expirydate": "25-07-2020", "mass": "794g"}
newvalues = {"$set":{"NewProducts": "Carrots","amount_purchased":10, "expirydate": "25-08-2020", "mass": "1kg"}}

mynewcol.update_one(myquery, newvalues)
#print "NewProducts" after the update:
for x in mynewcol.find():
  print(x)

#Track (Search/Filter) for the least 5 brands in your products.
myquery = {"expirydate": { "$regex": "^1" } }
mydoc = mynewcol.find(myquery)
for x in mydoc:
    print(x)
# Out:
# {'_id': 15, 'NewProducts': 'Vanilla', 'amount_purchased': 40, 'expirydate': '18-07-2020', 'mass': '80g'}
# {'_id': 4, 'NewProducts': 'Tex', 'amount_purchased': 45, 'expirydate': '20-09-2020', 'mass': '78g'}
# {'_id': 11, 'NewProducts': 'Steak & Kidney', 'amount_purchased': 25, 'expirydate': '17-07-2020', 'mass': '126g'}
# {'_id': 19, 'NewProducts': 'Spinach', 'amount_purchased': 10, 'expirydate': '29-07-2020', 'mass': '250g'}
# {'_id': 8, 'NewProducts': 'Spar-letta', 'amount_purchased': 10, 'expirydate': '17-11-2022', 'mass': '1.5 litre'}
# {'_id': 1, 'NewProducts': 'Simba', 'amount_purchased': 45, 'expirydate': '01-10-2021', 'mass': '125g'}
# {'_id': 21, 'NewProducts': 'Ricoffy', 'amount_purchased': 50, 'expirydate': '05-10-2027', 'mass': '170g'}
# {'_id': 20, 'NewProducts': 'Potatoes', 'amount_purchased': 5, 'expirydate': '27-07-2020', 'mass': '25kg'}
# {'_id': 14, 'NewProducts': 'Plums', 'amount_purchased': 8, 'expirydate': '15-08-2020', 'mass': '100g'}
# ...
